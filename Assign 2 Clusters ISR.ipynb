# %%
texts = {
    "C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file1.txt": "Machine learning is a branch of artificial intelligence.",
    "C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file2.txt": "Artificial intelligence and machine learning are related fields.",
    "C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file3.txt": "Football is the most popular sport in the world.",
    "C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file4.txt": "Cricket and football are played all over the world.",
    "C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file5.txt": "Python is used for data science and machine learning."
}

for filename, content in texts.items():
    with open(filename, "w", encoding="utf-8") as f:
        f.write(content)
        print(f"{filename} created successfully.")

print("\nAll 5 files created in current directory ✅")
# Out:
# C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file1.txt created successfully.
# C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file2.txt created successfully.
# C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file3.txt created successfully.
# C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file4.txt created successfully.
# C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file5.txt created successfully.
#
# All 5 files created in current directory ✅

# %%
# === Single-Pass Clustering Algorithm for Text Documents ===
# CO4 - Distributed and Multimedia Information Retrieval

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# --- Step 1: Mention the files manually ---
filenames = ["C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file1.txt", "C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file2.txt", "C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file3.txt", "C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file4.txt", "C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file5.txt"]

# --- Step 2: Read file contents ---
documents = [open(f, "r", encoding="utf-8").read() for f in filenames]

# --- Step 3: Convert to TF-IDF vectors ---
vectorizer = TfidfVectorizer(stop_words="english")
tfidf = vectorizer.fit_transform(documents)

# --- Step 4: Set similarity threshold ---
THRESHOLD = 0.3

# --- Step 5: Single-Pass Clustering ---
clusters, centroids = [], []

for i, vec in enumerate(tfidf):
    assigned = False
    for j, c in enumerate(centroids):
        sim = cosine_similarity(vec, c)[0][0]
        if sim >= THRESHOLD:
            clusters[j].append(filenames[i])
            centroids[j] = (centroids[j] + vec) / 2
            assigned = True
            break
    if not assigned:
        clusters.append([filenames[i]])
        centroids.append(vec)

# --- Step 6: Display results ---
for i, c in enumerate(clusters, 1):
    print(f"Cluster {i}: {c}")
# Out:
# Cluster 1: ['C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file1.txt', 'C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file2.txt']
# Cluster 2: ['C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file3.txt', 'C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file4.txt']
# Cluster 3: ['C:/Users/HP/OneDrive/Desktop/ISR/Assign 2/file5.txt']
